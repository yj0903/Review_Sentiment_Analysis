# %% [markdown]
# ### sns 데이터

# %%
import pandas as pd

# 파일 경로 설정
file_path = "ratings.txt"

# 텍스트 파일을 데이터프레임으로 변환
try:
    # 파일을 데이터프레임으로 읽기
    df = pd.read_csv(file_path, delimiter='\t')  # 만약 구분자가 다르다면 delimiter를 해당 값으로 변경
    # 또는
    # df = pd.read_table(file_path)  # 구분자가 탭('\t')인 경우 read_table 함수도 사용 가능

    # 데이터프레임 내용 출력
    print(df.head())
except FileNotFoundError:
    print(f"파일 '{file_path}'을 찾을 수 없습니다.")
except pd.errors.EmptyDataError:
    print(f"파일 '{file_path}'은(는) 비어 있습니다.")
except pd.errors.ParserError:
    print(f"파일 '{file_path}'을(를) 파싱하는 중에 오류가 발생했습니다.")
# Out:
#          id                                           document  label
# 0   8112052                                어릴때보고 지금다시봐도 재밌어요ㅋㅋ      1
# 1   8132799  디자인을 배우는 학생으로, 외국디자이너와 그들이 일군 전통을 통해 발전해가는 문화산...      1
# 2   4655635               폴리스스토리 시리즈는 1부터 뉴까지 버릴께 하나도 없음.. 최고.      1
# 3   9251303  와.. 연기가 진짜 개쩔구나.. 지루할거라고 생각했는데 몰입해서 봤다.. 그래 이런...      1
# 4  10067386                        안개 자욱한 밤하늘에 떠 있는 초승달 같은 영화.      1

# %%
df.sort_value(by)
# Out:
#               id                                           document  label
# 0        8112052                                어릴때보고 지금다시봐도 재밌어요ㅋㅋ      1
# 1        8132799  디자인을 배우는 학생으로, 외국디자이너와 그들이 일군 전통을 통해 발전해가는 문화산...      1
# 2        4655635               폴리스스토리 시리즈는 1부터 뉴까지 버릴께 하나도 없음.. 최고.      1
# 3        9251303  와.. 연기가 진짜 개쩔구나.. 지루할거라고 생각했는데 몰입해서 봤다.. 그래 이런...      1
# 4       10067386                        안개 자욱한 밤하늘에 떠 있는 초승달 같은 영화.      1
# ...          ...                                                ...    ...
# 199995   8963373                                     포켓 몬스터 짜가 ㅡㅡ;;      0
# 199996   3302770                                              쓰.레.기      0
# 199997   5458175                  완전 사이코영화. 마지막은 더욱더 이 영화의질을 떨어트린다.      0
# 199998   6908648                왜난 재미없었지 ㅠㅠ 라따뚜이 보고나서 스머프 봐서 그런가 ㅋㅋ      0
# 199999   8548411                                    포풍저그가나가신다영차영차영차      0
#
# [200000 rows x 3 columns]

# %% [markdown]
# ### 쇼핑몰 데이터

# %%
import os
import json  
import pandas as pd


# './data' 경로 설정
name = '01. 패션'
data_path = './Sample/02.라벨링데이터/쇼핑몰/'+ name

# './data' 경로 안에 있는 모든 폴더 리스트 가져오기
subdirectories = [d for d in os.listdir(data_path) if os.path.isdir(os.path.join(data_path, d))]

# 모든 폴더 안의 JSON 파일을 불러와 DataFrame으로 추가
dfs = []
for subdir in subdirectories:
    subdir_path = os.path.join(data_path, subdir)
    json_files = [f for f in os.listdir(subdir_path) if f.endswith('.json')]
    
    for json_file in json_files:
        file_path = os.path.join(subdir_path, json_file)
        with open(file_path, 'r', encoding='utf-8') as file:
            data = json.load(file)
            dfs.append(pd.json_normalize(data, sep='_'))

# 모든 DataFrame을 합치기
result_df = pd.concat(dfs, ignore_index=True)
result_df
# Out:
#         Index                                            RawText Source
# 0           7                                  가격이 착하고 디자인이 예쁩니다    쇼핑몰  \
# 1           9                    싸고  디자인이 예뻐요. . 정말  가성비 가심비 입니다    쇼핑몰
# 2          15  편하고  디자인이 예뻐요  가격도  좋아요   시원해요  빨리 마르고  이것만  입게되요    쇼핑몰
# 3          17                          너무 착한가격에 감사합니다 윈하는 색은 없지만    쇼핑몰
# 4          18  가격이  너무 좋아서  블랙 구매했습니다  그런데 소재도  맘에  들어  흰색도  ...    쇼핑몰
# ...       ...                                                ...    ...
# 44991  198798  일단 색상이 넘 좋으네요.  첫 커리어가 ㅇㅇㅇ 였는데, 금방 바퀴가 부셔져서 버리...    쇼핑몰
# 44992  198799  가격대비 괜찮아요 근데 어깨에 매는 사이즈 끈이 자꾸 빠져서 그냥 손으로 들고 다녔...    쇼핑몰
# 44993  198803  20년전에 화물용하나에 이십만원준거 무겁고 바퀴부서지고 이건 가격  너무좋고 견고해...    쇼핑몰
# 44994  198805  무늬가 고급스럽고 이쁘네요^^ 여행갈때 5종세트만 있으면 따로 가방 준비할건 없을듯...    쇼핑몰
# 44995  198806               빠른 배송, 색상도 좋으네요 4종류 용도에 맞게 사용하기 편리해요    쇼핑몰
#
#       Domain MainCategory                ProductName ReviewScore Syllable
# ...

# %%
# 결과 출력
result_df.to_csv('./data/'+name+'.csv', header = True, index = False, encoding='utf-8-sig')
